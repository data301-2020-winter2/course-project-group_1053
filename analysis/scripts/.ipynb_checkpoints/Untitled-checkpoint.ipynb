# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import os
os.chdir('..')
from scripts.project_functions import load_and_process
from scripts.project_functions import add_medalpts

# %%
df = load_and_process("../data/raw/Summer-Olympic-medals-1976-to-2008 2.csv")
df.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
add_medalpts(df)
df = df.copy().drop(['Country_Code', 'City', 'Athlete'], axis=1)
df.head()
# Out:
#      Year     Sport Discipline           Event Gender        Country  \
# 0  1976.0  Aquatics     Diving  3m springboard  Women   East Germany
# 1  1976.0  Aquatics     Diving  3m springboard    Men   Soviet Union
# 2  1976.0  Aquatics     Diving  3m springboard    Men  United States
# 3  1976.0  Aquatics     Diving  3m springboard    Men          Italy
# 4  1976.0  Aquatics     Diving    10m platform  Women  United States
#
#   Event_gender   Medal  Medal_Points
# 0            W  Silver             2
# 1            M  Bronze             1
# 2            M    Gold             4
# 3            M  Silver             2
# 4            W  Bronze             1

# %%
anualpts = (df.groupby(['Country', 'Year']).Medal_Points.sum()
            .sort_values(ascending=False)
            .reset_index())
anualpts
# Out:
#            Country    Year  Medal_Points
# 0     Soviet Union  1980.0          1145
# 1    United States  1984.0           952
# 2    United States  2008.0           799
# 3    United States  1996.0           788
# 4     Soviet Union  1988.0           761
# ..             ...     ...           ...
# 554       Thailand  1988.0             1
# 555       Barbados  2000.0             1
# 556         Mexico  1996.0             1
# 557         Greece  1988.0             1
# 558    Afghanistan  2008.0             1
#
# [559 rows x 3 columns]

# %%
totalpts = (df.groupby('Country')
            .Medal_Points.sum()
            .sort_values(ascending=False)
            .reset_index())
totalpts
# Out:
#            Country  Medal_Points
# 0    United States          5359
# 1     Soviet Union          2623
# 2        Australia          1716
# 3     East Germany          1674
# 4            China          1633
# ..             ...           ...
# 122        Eritrea             1
# 123       Djibouti             1
# 124       Bermuda*             1
# 125       Barbados             1
# 126      Macedonia             1
#
# [127 rows x 2 columns]

# %%
sns.lineplot(x='Year', y='Medal_Points', hue = 'Country', data=anualpts[anualpts['Country'].isin(list(totalpts.Country[:10]))])
plt.legend(loc="center right", bbox_to_anchor=(1.4, 0.5))
